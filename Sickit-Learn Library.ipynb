# %% [markdown]
# # Complete Sickit-Learn Course

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_csv('./housing.csv')
housing_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Lets explore the shape of our DataSet:
housing_data.shape
# Out:
# (20640, 10)

# %% [markdown]
# ##### Lets Clean our DataSet from any missing value

# %%
# But its common that your real-life DataSet will contain missing values.
# So we have to clean it up using pandas useful method called `dropna()`
housing_data = housing_data.dropna()
# now lets explore the shape again..
housing_data.shape
# Out:
# (20433, 10)

# %% [markdown]
# ##### Lets Explore Some Statistcs Info. About Our DataSet

# %%
housing_data.describe()
## As you can see, .describe() will return all numeric columns after performing statistics operations on each of them.
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ##### But what about the non-numeric columns !

# %%
# Lets see what are the categories of this column (avaliable values of this column)
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# ##### Our target variable is `median_house_value`

# %% [markdown]
# #### Lets try to extract any pattern between any feature and the target

# %%
fig, ax = plt.subplots(figsize = (12, 8))
plt.scatter(housing_data['total_rooms'], housing_data['median_house_value'])
plt.xlabel('Total Rooms')
plt.ylabel('median_house_value')
plt.show()

# %% [markdown]
# #### I can't find any relation from the above graph, but here what i can understand from this graph, there is a cap (upper limit) at `median_house_value = 500000`

# %%
# Lets try another feature ..
## Note that we should update the fig, ax everytime
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(housing_data['housing_median_age'],
            housing_data['median_house_value'])
plt.xlabel('median house age')
plt.ylabel('median house value')
plt.show()

# %% [markdown]
# #### I still can't find any relation from the above graph, but here what i can understand from this graph, there is a cap (upper limit) at `housing_median_Age = around 52`

# %%
# Lets explore another feature:
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(housing_data['median_income']*10000,
            housing_data['median_house_value'])
plt.xlabel('Median Income "$"')
plt.ylabel('Median House Value')
plt.show()

# %% [markdown]
# #### Oh, Finally a relation, as you can see as the income increase, the house price increase.
# #### Important Hint, there is still a cap at `house value = 500000`

# %% [markdown]
# ### Can we find a correlation between all features and the target

# %%
housing_data_corr = housing_data.corr()

# %% [markdown]
# ##### I need you to focus on the relation btn `median_house_value` and `housing_median_age` and also `median_income`

# %%
housing_data_corr
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# ...

# %% [markdown]
# ##### we can represent the correlation relations in better way ..

# %%
fig, ax = plt.subplots(figsize = (12,10))
sns.heatmap(housing_data_corr, annot=True)
plt.show()

# %% [markdown]
# ### as we notice from all graphs above that there are a lot of values that limited when the `median_house_value = 500000`, so its time to fix this problem.
# ### First Lets see how many observations/rows we have that suffered from this limitation..

# %%
housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %% [markdown]
# ## WOW!! our dataset has around 20000 rows, and around 1000 of them are sckewd .. this is a problem
# ## Let me tell you something that you should remember it in real-life projects, when you face a problem like that, don't apply the next action that i will do, you will learn later a lot of methods and techniques to solve the `sckew` behaviour in your dataset

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
# for simplicity, lets drop all these rows 
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)

# %%
housing_data.shape
# Out:
# (19475, 10)

# %% [markdown]
# ### Our second problem was that ML models can't deal with non-numeric values, and do you remember that we have one column with non-numeric type !

# %%
housing_data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# #### there are many solutions to this problem, i will solve it now by using `one-hot encoding` technique

# %%
housing_data = pd.get_dummies(housing_data, columns=['ocean_proximity'])
# Lets Explore the shape now, remember it was 10 columns
housing_data.shape
# Out:
# (19475, 14)

# %%
housing_data
# please see the effect after transforming string features to numeric fetures, just explore the new 4 columsn at the end of the next table
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# # Now we are Ready :D

# %% [markdown]
# ### 1) Construct the features dataFrame and target dataFrame

# %%
features = housing_data.drop('median_house_value', axis=1)
features
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
target = housing_data['median_house_value']
target
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 19475, dtype: float64

# %% [markdown]
# ### 2) Split your dataset into training dataset and testing dataset, its most common to use 80% for training and 20% for testing

# %%
from sklearn.model_selection import train_test_split
features_train, features_test, target_train, targe_test = train_test_split(features, target, test_size=0.2)

# %%
features_train.shape, features_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %% [markdown]
# ### 3) use sickit-learn APIs to build your model

# %%
# => Step [1] : Import the Linear regression model/Estimator from sklearn.linear_model
from sklearn.linear_model import LinearRegression

# => Step [2] : instantiate a linear Regression Object
## QUESTION (1) 
#### I know you may wonder what is the meaning of (normalize = True) ???
#### ANSWER : normalize scales all numeric features to be between 0 and 1, having all features in the same scale can improve the performance of your ML model
## QUESTION (2)
#### so now tell me what is the usage of .fit() ?
#### ANSWER : the .fit() is API to train your model with provided features_Train and target_Train datasets
linear_model = LinearRegression(normalize = True).fit(features_train,target_train)

# %% [markdown]
# #### Congrats, you trained your first ML model ^_^

# %% [markdown]
# ### 4) Lets now Evaluate your ML model

# %%
Training_DataSet_Score = linear_model.score(features_train,
                                            target_train)
print("Training Score on the Training dataset : ", Training_DataSet_Score)
# Out:
# Training Score on the Training dataset :  0.6161689426236128

# %%
# i will assign all used features to build our model
predictors = features_train.columns
#predictors.size # = 13
predictors
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %% [markdown]
# ##### Remember the linear regression EQN ?
# ###### `y = wx + b` where `w` is the coeff of each feature which represents the effect of each feture to our predicted result, if `w is +` so if this feature increase, the predicted value will be closer to the actual value, the opposite when `w is -`

# %%
# Lets explore the coeff that our model used 
coeff = pd.DataFrame(linear_model.coef_, predictors, columns=['Coeff']).sort_values(by='Coeff', ascending=True)
coeff
# Out:
#                                     Coeff
# ocean_proximity_INLAND      -25797.590751
# longitude                   -23878.118182
# latitude                    -22500.701354
# population                     -37.599640
# total_rooms                     -6.956665
# households                      69.966096
# total_bedrooms                  83.404458
# housing_median_age             892.173193
# ocean_proximity_NEAR BAY      6734.944468
# ocean_proximity_<1H OCEAN    13291.490788
# ocean_proximity_NEAR OCEAN   16126.137019
# median_income                38433.244252
# ocean_proximity_ISLAND      206810.880868

# %% [markdown]
# ### 5) start use your fully trained model to predict something with a new dataset

# %%
# use mode.predict(NewDataSet)
predicted_House_Price = linear_model.predict(features_test)
# lets make a dataframe to easily compare between the actual and predicted values
predicted_vs_actual = pd.DataFrame({
    "Predicted" : predicted_House_Price,
    "Actual" : targe_test
})
# explore random 10 rows of this dataframe to see the results
predicted_vs_actual.sample(10)
# Out:
#            Predicted    Actual
# 7822   190646.679643  216600.0
# 2275    82457.948651   66500.0
# 7673   188538.877419  165100.0
# 16368  124598.708041  101600.0
# 14330  222714.920484  137500.0
# 11227  248370.642505  254800.0
# 4474   190065.023878  144600.0
# 19677  194547.101277   71800.0
# 15534  189763.553673  190500.0
# 15407  150388.956034   97000.0

# %% [markdown]
# ### 6) Evaluate your model

# %% [markdown]
# #### usually R2 is a good evaluator, R2 also called least square error

# %%
from sklearn.metrics import r2_score
R2_metric = r2_score(targe_test, predicted_House_Price)
R2_metric
# Out:
# 0.5938863233755747

# %% [markdown]
# #### From the Above value, you can observe that your model behave with new data < its behave with trained data.. this is not good btw

# %% [markdown]
# ### Lets plot actual vs predicted
# ##### you know that when we use plt.plot() the default graph will be a line plot, right !? study matplotlib and you will know that.

# %%
fig, ax = plt.subplots(figsize = (12, 10))
plt.plot(predicted_vs_actual['Predicted'], label = "Predicted")
plt.plot(predicted_vs_actual['Actual'], label = "Actual")
plt.legend()
plt.show()

# %% [markdown]
# #### Calm down .. lets take a smaller number of observations so we can see the result clearly ..

# %%
sample_predicted_vs_actual = predicted_vs_actual.sample(100).reset_index()
sample_predicted_vs_actual
# Out:
#     index      Predicted    Actual
# 0   10233  186635.377079  193800.0
# 1   10316  275272.451375  304900.0
# 2    8733  216918.177123  225000.0
# 3   17739  273438.916434  241900.0
# 4    8605  225157.267371  281900.0
# ..    ...            ...       ...
# 95   4685  234707.466501  450000.0
# 96    757  196167.512687  161200.0
# 97  11485  273218.407269  255700.0
# 98  19705  158963.328840   96200.0
# 99  10064   53608.073687   85000.0
#
# [100 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize = (12, 10))
plt.plot(sample_predicted_vs_actual['Predicted'], label = "Predicted")
plt.plot(sample_predicted_vs_actual['Actual'], label = "Actual")
plt.legend()
plt.show()
